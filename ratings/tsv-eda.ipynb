# %%
import pandas as pd

tsv_2024 = pd.read_csv(f'data/imdb/movies_2024.tsv', low_memory=False, delimiter='\t', on_bad_lines="skip")
# Out:
# id                              107
# imdb                            107
# original_language               107
# overview                        106
# popularity                      107
# release_date                    107
# vote_average                    107
# vote_count                      107
# production_companies_names       96
# production_companies_id          96
# production_companies_country     83
# budget                          107
# revenue                         107
# dtype: int64

# %%
tsv_2024.groupby('original_language').count()
# Out:
#                    id  imdb  overview  popularity  release_date  vote_average  \
# original_language
# 2024-11-14          1     1         1           1             1             1
# 2025-01-15          1     1         1           1             1             1
# ar                 27    27        27          27            27            27
# as                  1     1         1           1             1             1
# bg                  2     2         2           2             2             2
# ...                ..   ...       ...         ...           ...           ...
# uz                  1     1         1           1             1             1
# vi                  6     6         6           6             6             6
# yo                  1     1         1           1             1             1
# zh                 67    67        65          67            66            67
# zu                  2     2         2           2             2             2
#
#                    vote_count  production_companies_names  \
# original_language
# 2024-11-14                  1                           1
# 2025-01-15                  1                           1
# ar                         27                          27
# as                          1                           0
# bg                          2                           1
# ...                       ...                         ...
# uz                          1                           1
# vi                          6                           6
# yo                          1                           0
# zh                         67                          60
# zu                          2                           2
#
#                    production_companies_id  production_companies_country  \
# original_language
# 2024-11-14                               1                             0
# 2025-01-15                               1                             0
# ar                                      27                            25
# as                                       0                             0
# bg                                       1                             1
# ...                                    ...                           ...
# uz                                       1                             0
# vi                                       6                             4
# yo                                       0                             0
# zh                                      60                            58
# zu                                       2                             2
#
#                    budget  revenue
# original_language
# 2024-11-14              0        0
# 2025-01-15              0        0
# ar                     27       27
# as                      1        1
# bg                      2        2
# ...                   ...      ...
# uz                      1        1
# vi                      6        6
# yo                      1        1
# zh                     67       67
# zu                      2        2
#
# [72 rows x 12 columns]

# %%
tsv_2024[tsv_2024['original_language'] == 'gl']
# Out:
#           id        imdb original_language  \
# 853  1172611  tt26164896                gl
#
#                                               overview  popularity  \
# 853  In As Neves, a mountain village, a group of te...      0.2251
#
#     release_date vote_average vote_count  \
# 853   2024-05-10          6.2          2
#
#                production_companies_names production_companies_id  \
# 853  Aquí y Allí Films|Cósmica Producións            27991|146415
#
#     production_companies_country  budget  revenue
# 853                          ES|     0.0      0.0
